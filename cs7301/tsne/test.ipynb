# %%
import wget
wget.download('http://deeplearning.net/data/mnist/mnist.pkl.gz')
# Out:
# 'mnist.pkl.gz'

# %%
import numpy as np
import gzip, _pickle
from tsne import bh_sne
import matplotlib.pyplot as plt
f = gzip.open("mnist.pkl.gz", "rb")
train, val, test = _pickle.load(f,encoding='bytes')
f.close()
X = np.asarray(np.vstack((train[0], val[0], test[0])), dtype=np.float64)
y = np.hstack((train[1], val[1], test[1]))
X_2d = bh_sne(X)
plt.rcParams['figure.figsize'] = 20, 20
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eb09ead8ac85> in <module>()
#       8 X = np.asarray(np.vstack((train[0], val[0], test[0])), dtype=np.float64)
#       9 y = np.hstack((train[1], val[1], test[1]))
# ---> 10 X_2d = bh_sne(X)
#      11 plt.rcParams['figure.figsize'] = 20, 20
#      12 plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y)
#
# /Users/jiadao/PycharmProjects/untitled/venv/lib/python3.6/site-packages/tsne/__init__.py in bh_sne(data, pca_d, d, perplexity, theta, random_state, copy_data)
#      57
#      58     tsne = BH_SNE()
# ---> 59     Y = tsne.run(X, N, X.shape[1], d, perplexity, theta, seed)
#      60     return Y
#      61
#
# KeyboardInterrupt:

# %%
import numpy as np
import bhtsne

data = np.loadtxt("/Users/jiadao/Desktop/sample_mnist.csv", skiprows=1)

embedding_array = bhtsne.run_bh_tsne(data, initial_dims=data.shape[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-bf3fb782625a> in <module>()
#       2 import bhtsne
#       3
# ----> 4 data = np.loadtxt("/Users/jiadao/Desktop/sample_mnist.csv", skiprows=1)
#       5
#       6 embedding_array = bhtsne.run_bh_tsne(data, initial_dims=data.shape[1])
#
# /Users/jiadao/PycharmProjects/Py3/venv/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1090         # converting the data
#    1091         X = None
# -> 1092         for x in read_data(_loadtxt_chunksize):
#    1093             if X is None:
#    1094                 X = np.array(x, dtype)
#
# /Users/jiadao/PycharmProjects/Py3/venv/lib/python3.6/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1017
# ...

# %%
g++ sptree.cpp tsne.cpp tsne_main.cpp -o bh_tsne -O2
# Out:
#   File "<ipython-input-1-e06ea0f3d085>", line 1
#     g++ sptree.cpp tsne.cpp tsne_main.cpp -o bh_tsne -O2
#                       ^
# SyntaxError: invalid syntax
